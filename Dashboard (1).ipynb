# %% [markdown]
# [DIY Covid-19 Dashboard Kit](https://github.com/fsmeraldi/diy-covid19dash) (C) Fabrizio Smeraldi, 2020 ([f.smeraldi@qmul.ac.uk](mailto:f.smeraldi@qmul.ac.uk) - [web](http://www.eecs.qmul.ac.uk/~fabri/)). All rights reserved.

# %% [markdown]
# # DIY Covid-19 Dashboard

# %% [markdown]
# This is a template for your DIY Covid Dashboard, to which you can add the code you developed in the previous notebooks. The dashboard will be displayed using [voila](https://voila.readthedocs.io/en/stable/index.html), a Python dashboarding tool that converts notebooks to standalone dashboards. Contrary to the other libraries we have seen, the ```voila``` package must be installed using *pip* or *conda* but it does not need to be imported - it rather acts at the level of the notebook server. Package ```voila``` is already installed on the EECS JupyterHub as well as in the binder - to install it locally, follow the [instructions](https://voila.readthedocs.io/en/stable/install.html) online.
#
# Broadly speaking, Voila acts by **running all the cells in your notebook** when the dashboard is first loaded; it then hides all code cells and displays all markdown cells and any outputs, including widgets. However, the code is still there in the background and handles any interaction with the widgets. To view this dashboard template rendered in Voila click [here](https://mybinder.org/v2/gh/fsmeraldi/diy-covid19dash/main?urlpath=%2Fvoila%2Frender%2FDashboard.ipynb).

# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from uk_covid19 import Cov19API

# %%
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Load initial data from disk
#
# You should include "canned" data in ```.json``` files along with your dashboard. When the dashboard starts, it should load that data (the code below will be hidden when the dashboard is rendered by Voila).

# %%
with open("case_and_admission.json", "rt") as INFILE:
    jsondata=json.load(INFILE)

# %% [markdown]
# ## Wrangle the data
#
# The dashboard should contain the logic to wrangle the raw data into a ```DataFrame``` (or more than one, as required) that will be used for plotting. The wrangling code should be put into a function and called on the data from the JSON file (we'll need to call it again on any data downloaded from the API).  In this template, we just pretend we are wrangling ```rawdata``` and generate a dataframe with some random data

# %%
with open("case_and_admission.json", "rt") as INFILE:
    jsondata=json.load(INFILE)
datalist=jsondata['data']
datalist
# Out:
# [{'date': '2021-10-25', 'vax': None, 'admissions': 865},
#  {'date': '2021-10-24', 'vax': None, 'admissions': 829},
#  {'date': '2021-10-23', 'vax': None, 'admissions': 756},
#  {'date': '2021-10-22', 'vax': None, 'admissions': 760},
#  {'date': '2021-10-21', 'vax': None, 'admissions': 799},
#  {'date': '2021-10-20', 'vax': None, 'admissions': 903},
#  {'date': '2021-10-19', 'vax': None, 'admissions': 894},
#  {'date': '2021-10-18', 'vax': None, 'admissions': 896},
#  {'date': '2021-10-17', 'vax': None, 'admissions': 828},
#  {'date': '2021-10-16', 'vax': None, 'admissions': 743},
#  {'date': '2021-10-15', 'vax': None, 'admissions': 752},
#  {'date': '2021-10-14', 'vax': None, 'admissions': 730},
#  {'date': '2021-10-13', 'vax': None, 'admissions': 752},
#  {'date': '2021-10-12', 'vax': None, 'admissions': 760},
#  {'date': '2021-10-11', 'vax': None, 'admissions': 685},
#  {'date': '2021-10-10', 'vax': None, 'admissions': 606},
#  {'date': '2021-10-09', 'vax': None, 'admissions': 613},
#  {'date': '2021-10-08', 'vax': None, 'admissions': 619},
#  {'date': '2021-10-07', 'vax': None, 'admissions': 634},
#  {'date': '2021-10-06', 'vax': None, 'admissions': 632},
#  {'date': '2021-10-05', 'vax': None, 'admissions': 658},
#  {'date': '2021-10-04', 'vax': None, 'admissions': 627},
#  {'date': '2021-10-03', 'vax': None, 'admissions': 577},
#  {'date': '2021-10-02', 'vax': None, 'admissions': 549},
#  {'date': '2021-10-01', 'vax': None, 'admissions': 520},
#  {'date': '2021-09-30', 'vax': None, 'admissions': 552},
#  {'date': '2021-09-29', 'vax': None, 'admissions': 625},
#  {'date': '2021-09-28', 'vax': 29670, 'admissions': 596},
#  {'date': '2021-09-27', 'vax': 28590, 'admissions': 617},
#  {'date': '2021-09-26', 'vax': 21476, 'admissions': 535},
#  {'date': '2021-09-25', 'vax': 43049, 'admissions': 520},
#  {'date': '2021-09-24', 'vax': 39567, 'admissions': 557},
#  {'date': '2021-09-23', 'vax': 41728, 'admissions': 577},
#  {'date': '2021-09-22', 'vax': 39676, 'admissions': 572},
#  {'date': '2021-09-21', 'vax': 39248, 'admissions': 602},
#  {'date': '2021-09-20', 'vax': 41438, 'admissions': 606},
#  {'date': '2021-09-19', 'vax': 30458, 'admissions': 572},
#  {'date': '2021-09-18', 'vax': 66134, 'admissions': 560},
#  {'date': '2021-09-17', 'vax': 55257, 'admissions': 540},
#  {'date': '2021-09-16', 'vax': 58941, 'admissions': 672},
#  {'date': '2021-09-15', 'vax': 57096, 'admissions': 691},
#  {'date': '2021-09-14', 'vax': 56521, 'admissions': 701},
#  {'date': '2021-09-13', 'vax': 54807, 'admissions': 688},
#  {'date': '2021-09-12', 'vax': 42902, 'admissions': 658},
#  {'date': '2021-09-11', 'vax': 86068, 'admissions': 649},
#  {'date': '2021-09-10', 'vax': 78763, 'admissions': 680},
#  {'date': '2021-09-09', 'vax': 86592, 'admissions': 790},
#  {'date': '2021-09-08', 'vax': 75548, 'admissions': 900},
#  {'date': '2021-09-07', 'vax': 73004, 'admissions': 801},
#  {'date': '2021-09-06', 'vax': 69758, 'admissions': 831},
#  {'date': '2021-09-05', 'vax': 59265, 'admissions': 691},
#  {'date': '2021-09-04', 'vax': 116327, 'admissions': 752},
#  {'date': '2021-09-03', 'vax': 98122, 'admissions': 688},
#  {'date': '2021-09-02', 'vax': 103997, 'admissions': 788},
#  {'date': '2021-09-01', 'vax': 102086, 'admissions': 835},
#  {'date': '2021-08-31', 'vax': 105003, 'admissions': 798},
#  {'date': '2021-08-30', 'vax': 52137, 'admissions': 808},
#  {'date': '2021-08-29', 'vax': 64710, 'admissions': 701},
#  {'date': '2021-08-28', 'vax': 116583, 'admissions': 688},
#  {'date': '2021-08-27', 'vax': 115249, 'admissions': 749},
#  {'date': '2021-08-26', 'vax': 127267, 'admissions': 777},
#  {'date': '2021-08-25', 'vax': 142307, 'admissions': 843},
#  {'date': '2021-08-24', 'vax': 109221, 'admissions': 818},
#  {'date': '2021-08-23', 'vax': 113005, 'admissions': 831},
#  {'date': '2021-08-22', 'vax': 96246, 'admissions': 726},
#  {'date': '2021-08-21', 'vax': 174038, 'admissions': 757},
#  {'date': '2021-08-20', 'vax': 145473, 'admissions': 733},
#  {'date': '2021-08-19', 'vax': 153886, 'admissions': 824},
#  {'date': '2021-08-18', 'vax': 147569, 'admissions': 795},
#  {'date': '2021-08-17', 'vax': 120908, 'admissions': 832},
#  {'date': '2021-08-16', 'vax': 117998, 'admissions': 776},
#  {'date': '2021-08-15', 'vax': 101881, 'admissions': 719},
#  {'date': '2021-08-14', 'vax': 173718, 'admissions': 689},
#  {'date': '2021-08-13', 'vax': 143690, 'admissions': 694},
#  {'date': '2021-08-12', 'vax': 165425, 'admissions': 758},
#  {'date': '2021-08-11', 'vax': 145954, 'admissions': 747},
#  {'date': '2021-08-10', 'vax': 123721, 'admissions': 760},
#  {'date': '2021-08-09', 'vax': 112286, 'admissions': 665},
#  {'date': '2021-08-08', 'vax': 94332, 'admissions': 651},
#  {'date': '2021-08-07', 'vax': 184869, 'admissions': 630},
#  {'date': '2021-08-06', 'vax': 137172, 'admissions': 657},
#  {'date': '2021-08-05', 'vax': 143423, 'admissions': 693},
#  {'date': '2021-08-04', 'vax': 131581, 'admissions': 747},
#  {'date': '2021-08-03', 'vax': 108604, 'admissions': 680},
#  {'date': '2021-08-02', 'vax': 94425, 'admissions': 686},
#  {'date': '2021-08-01', 'vax': 92416, 'admissions': 645},
#  {'date': '2021-07-31', 'vax': 182825, 'admissions': 593},
#  {'date': '2021-07-30', 'vax': 142715, 'admissions': 650},
#  {'date': '2021-07-29', 'vax': 145472, 'admissions': 758},
#  {'date': '2021-07-28', 'vax': 131048, 'admissions': 728},
#  {'date': '2021-07-27', 'vax': 118328, 'admissions': 816},
#  {'date': '2021-07-26', 'vax': 115924, 'admissions': 830},
#  {'date': '2021-07-25', 'vax': 94435, 'admissions': 836},
#  {'date': '2021-07-24', 'vax': 177885, 'admissions': 734},
#  {'date': '2021-07-23', 'vax': 154761, 'admissions': 725},
#  {'date': '2021-07-22', 'vax': 156245, 'admissions': 827},
#  {'date': '2021-07-21', 'vax': 146281, 'admissions': 783},
#  {'date': '2021-07-20', 'vax': 126163, 'admissions': 805},
#  {'date': '2021-07-19', 'vax': 112544, 'admissions': 752},
#  {'date': '2021-07-18', 'vax': 105472, 'admissions': 698},
#  {'date': '2021-07-17', 'vax': 196422, 'admissions': 622},
#  {'date': '2021-07-16', 'vax': 163936, 'admissions': 593},
#  {'date': '2021-07-15', 'vax': 167152, 'admissions': 658},
#  {'date': '2021-07-14', 'vax': 151335, 'admissions': 636},
#  {'date': '2021-07-13', 'vax': 124905, 'admissions': 621},
#  {'date': '2021-07-12', 'vax': 99817, 'admissions': 610},
#  {'date': '2021-07-11', 'vax': 80755, 'admissions': 502},
#  {'date': '2021-07-10', 'vax': 174745, 'admissions': 442},
#  {'date': '2021-07-09', 'vax': 143603, 'admissions': 451},
#  {'date': '2021-07-08', 'vax': 135457, 'admissions': 488},
#  {'date': '2021-07-07', 'vax': 128226, 'admissions': 461},
#  {'date': '2021-07-06', 'vax': 109148, 'admissions': 458},
#  {'date': '2021-07-05', 'vax': 107977, 'admissions': 416},
#  {'date': '2021-07-04', 'vax': 85748, 'admissions': 390},
#  {'date': '2021-07-03', 'vax': 165665, 'admissions': 323},
#  {'date': '2021-07-02', 'vax': 142275, 'admissions': 307},
#  {'date': '2021-07-01', 'vax': 154177, 'admissions': 295},
#  {'date': '2021-06-30', 'vax': 138993, 'admissions': 331},
#  {'date': '2021-06-29', 'vax': 115484, 'admissions': 283},
#  {'date': '2021-06-28', 'vax': 107318, 'admissions': 244},
#  {'date': '2021-06-27', 'vax': 97993, 'admissions': 226},
#  {'date': '2021-06-26', 'vax': 172324, 'admissions': 223},
#  {'date': '2021-06-25', 'vax': 133375, 'admissions': 206},
#  {'date': '2021-06-24', 'vax': 136679, 'admissions': 194},
#  {'date': '2021-06-23', 'vax': 128688, 'admissions': 214},
#  {'date': '2021-06-22', 'vax': 210730, 'admissions': 182},
#  {'date': '2021-06-21', 'vax': None, 'admissions': 181},
#  {'date': '2021-06-20', 'vax': 78594, 'admissions': 171},
#  {'date': '2021-06-19', 'vax': 195646, 'admissions': 178},
#  {'date': '2021-06-18', 'vax': 162030, 'admissions': 185},
#  {'date': '2021-06-17', 'vax': 176158, 'admissions': 202},
#  {'date': '2021-06-16', 'vax': 180627, 'admissions': 177},
#  {'date': '2021-06-15', 'vax': 175703, 'admissions': 188},
#  {'date': '2021-06-14', 'vax': 174262, 'admissions': 185},
#  {'date': '2021-06-13', 'vax': 153449, 'admissions': 187},
#  {'date': '2021-06-12', 'vax': 276813, 'admissions': 137},
#  {'date': '2021-06-11', 'vax': 251641, 'admissions': 144},
#  {'date': '2021-06-10', 'vax': 248650, 'admissions': 162},
#  {'date': '2021-06-09', 'vax': 253913, 'admissions': 158},
#  {'date': '2021-06-08', 'vax': 252697, 'admissions': 147},
#  {'date': '2021-06-07', 'vax': 244107, 'admissions': 131},
#  {'date': '2021-06-06', 'vax': 217491, 'admissions': 121},
#  {'date': '2021-06-05', 'vax': 415644, 'admissions': 96},
#  {'date': '2021-06-04', 'vax': 321602, 'admissions': 96},
#  {'date': '2021-06-03', 'vax': 313526, 'admissions': 93},
#  {'date': '2021-06-02', 'vax': 288963, 'admissions': 101},
#  {'date': '2021-06-01', 'vax': 279285, 'admissions': 115},
#  {'date': '2021-05-31', 'vax': 154674, 'admissions': 98},
#  {'date': '2021-05-30', 'vax': 179424, 'admissions': 80},
#  {'date': '2021-05-29', 'vax': 381816, 'admissions': 69},
#  {'date': '2021-05-28', 'vax': 380855, 'admissions': 92},
#  {'date': '2021-05-27', 'vax': 374042, 'admissions': 83},
#  {'date': '2021-05-26', 'vax': 368554, 'admissions': 95},
#  {'date': '2021-05-25', 'vax': 327467, 'admissions': 88},
#  {'date': '2021-05-24', 'vax': 279672, 'admissions': 98},
#  {'date': '2021-05-23', 'vax': 220062, 'admissions': 77},
#  {'date': '2021-05-22', 'vax': 508013, 'admissions': 75},
#  {'date': '2021-05-21', 'vax': 371460, 'admissions': 85},
#  {'date': '2021-05-20', 'vax': 367142, 'admissions': 98},
#  {'date': '2021-05-19', 'vax': 309020, 'admissions': 93},
#  {'date': '2021-05-18', 'vax': 269283, 'admissions': 90},
#  {'date': '2021-05-17', 'vax': 210442, 'admissions': 74},
#  {'date': '2021-05-16', 'vax': 157687, 'admissions': 59},
#  {'date': '2021-05-15', 'vax': 353764, 'admissions': 70},
#  {'date': '2021-05-14', 'vax': 346425, 'admissions': 72},
#  {'date': '2021-05-13', 'vax': 378650, 'admissions': 74},
#  {'date': '2021-05-12', 'vax': 402524, 'admissions': 93},
#  {'date': '2021-05-11', 'vax': 308915, 'admissions': 79},
#  {'date': '2021-05-10', 'vax': 192723, 'admissions': 76},
#  {'date': '2021-05-09', 'vax': 160313, 'admissions': 76},
#  {'date': '2021-05-08', 'vax': 404510, 'admissions': 80},
#  {'date': '2021-05-07', 'vax': 414731, 'admissions': 77},
#  {'date': '2021-05-06', 'vax': 419232, 'admissions': 88},
#  {'date': '2021-05-05', 'vax': 348553, 'admissions': 96},
#  {'date': '2021-05-04', 'vax': 211639, 'admissions': 76},
#  {'date': '2021-05-03', 'vax': 99785, 'admissions': 98},
#  {'date': '2021-05-02', 'vax': 137400, 'admissions': 92},
#  {'date': '2021-05-01', 'vax': 329170, 'admissions': 68},
#  {'date': '2021-04-30', 'vax': 361758, 'admissions': 82},
#  {'date': '2021-04-29', 'vax': 395043, 'admissions': 80},
#  {'date': '2021-04-28', 'vax': 394152, 'admissions': 89},
#  {'date': '2021-04-27', 'vax': 313616, 'admissions': 128},
#  {'date': '2021-04-26', 'vax': 249768, 'admissions': 108},
#  {'date': '2021-04-25', 'vax': 227159, 'admissions': 107},
#  {'date': '2021-04-24', 'vax': 478008, 'admissions': 99},
#  {'date': '2021-04-23', 'vax': 394144, 'admissions': 124},
#  {'date': '2021-04-22', 'vax': 345675, 'admissions': 92},
#  {'date': '2021-04-21', 'vax': 339773, 'admissions': 126},
#  {'date': '2021-04-20', 'vax': 272929, 'admissions': 98},
#  {'date': '2021-04-19', 'vax': 215665, 'admissions': 138},
#  {'date': '2021-04-18', 'vax': 195871, 'admissions': 112},
#  {'date': '2021-04-17', 'vax': 458880, 'admissions': 135},
#  {'date': '2021-04-16', 'vax': 446025, 'admissions': 118},
#  {'date': '2021-04-15', 'vax': 363002, 'admissions': 127},
#  {'date': '2021-04-14', 'vax': 292383, 'admissions': 156},
#  {'date': '2021-04-13', 'vax': 257732, 'admissions': 153},
#  {'date': '2021-04-12', 'vax': 166273, 'admissions': 173},
#  {'date': '2021-04-11', 'vax': 160454, 'admissions': 175},
#  {'date': '2021-04-10', 'vax': 437442, 'admissions': 151},
#  {'date': '2021-04-09', 'vax': 404206, 'admissions': 167},
#  {'date': '2021-04-08', 'vax': 403212, 'admissions': 167},
#  {'date': '2021-04-07', 'vax': 372241, 'admissions': 189},
#  {'date': '2021-04-06', 'vax': 162466, 'admissions': 183},
#  {'date': '2021-04-05', 'vax': 54060, 'admissions': 188},
#  {'date': '2021-04-04', 'vax': 39491, 'admissions': 156},
#  {'date': '2021-04-03', 'vax': 157903, 'admissions': 179},
#  {'date': '2021-04-02', 'vax': 215754, 'admissions': 178},
#  {'date': '2021-04-01', 'vax': 411998, 'admissions': 180},
#  {'date': '2021-03-31', 'vax': 341748, 'admissions': 225},
#  {'date': '2021-03-30', 'vax': 233828, 'admissions': 217},
#  {'date': '2021-03-29', 'vax': 137405, 'admissions': 206},
#  {'date': '2021-03-28', 'vax': 127078, 'admissions': 221},
#  {'date': '2021-03-27', 'vax': 201335, 'admissions': 217},
#  {'date': '2021-03-26', 'vax': 250962, 'admissions': 245},
#  {'date': '2021-03-25', 'vax': 198206, 'admissions': 288},
#  {'date': '2021-03-24', 'vax': 208013, 'admissions': 277},
#  {'date': '2021-03-23', 'vax': 134547, 'admissions': 295},
#  {'date': '2021-03-22', 'vax': 64436, 'admissions': 294},
#  {'date': '2021-03-21', 'vax': 30418, 'admissions': 279},
#  {'date': '2021-03-20', 'vax': 70449, 'admissions': 287},
#  {'date': '2021-03-19', 'vax': 100730, 'admissions': 283},
#  {'date': '2021-03-18', 'vax': 104609, 'admissions': 351},
#  {'date': '2021-03-17', 'vax': 90906, 'admissions': 343},
#  {'date': '2021-03-16', 'vax': 62909, 'admissions': 364},
#  {'date': '2021-03-15', 'vax': 32082, 'admissions': 431},
#  {'date': '2021-03-14', 'vax': 14378, 'admissions': 357},
#  {'date': '2021-03-13', 'vax': 38640, 'admissions': 385},
#  {'date': '2021-03-12', 'vax': 67514, 'admissions': 386},
#  {'date': '2021-03-11', 'vax': 69680, 'admissions': 449},
#  {'date': '2021-03-10', 'vax': 70960, 'admissions': 494},
#  {'date': '2021-03-09', 'vax': 47151, 'admissions': 483},
#  {'date': '2021-03-08', 'vax': 23800, 'admissions': 501},
#  {'date': '2021-03-07', 'vax': 9133, 'admissions': 461},
#  {'date': '2021-03-06', 'vax': 21688, 'admissions': 528},
#  {'date': '2021-03-05', 'vax': 37235, 'admissions': 487},
#  {'date': '2021-03-04', 'vax': 45045, 'admissions': 596},
#  {'date': '2021-03-03', 'vax': 44001, 'admissions': 607},
#  {'date': '2021-03-02', 'vax': 27652, 'admissions': 683},
#  {'date': '2021-03-01', 'vax': 12632, 'admissions': 704},
#  {'date': '2021-02-28', 'vax': 9388, 'admissions': 662},
#  {'date': '2021-02-27', 'vax': 15584, 'admissions': 624},
#  {'date': '2021-02-26', 'vax': 16226, 'admissions': 718},
#  {'date': '2021-02-25', 'vax': 16168, 'admissions': 832},
#  {'date': '2021-02-24', 'vax': 14209, 'admissions': 874},
#  {'date': '2021-02-23', 'vax': 9581, 'admissions': 976},
#  {'date': '2021-02-22', 'vax': 5344, 'admissions': 980},
#  {'date': '2021-02-21', 'vax': 2346, 'admissions': 1009},
#  {'date': '2021-02-20', 'vax': 2432, 'admissions': 904},
#  {'date': '2021-02-19', 'vax': 3895, 'admissions': 1068},
#  {'date': '2021-02-18', 'vax': 4561, 'admissions': 1149},
#  {'date': '2021-02-17', 'vax': 4497, 'admissions': 1233},
#  {'date': '2021-02-16', 'vax': 3128, 'admissions': 1311},
#  {'date': '2021-02-15', 'vax': 1854, 'admissions': 1322},
#  {'date': '2021-02-14', 'vax': 837, 'admissions': 1364},
#  {'date': '2021-02-13', 'vax': 2186, 'admissions': 1240},
#  {'date': '2021-02-12', 'vax': 3733, 'admissions': 1318},
#  {'date': '2021-02-11', 'vax': 4646, 'admissions': 1440},
#  {'date': '2021-02-10', 'vax': 4092, 'admissions': 1535},
#  {'date': '2021-02-09', 'vax': 2173, 'admissions': 1531},
#  {'date': '2021-02-08', 'vax': 1419, 'admissions': 1739},
#  {'date': '2021-02-07', 'vax': 312, 'admissions': 1675},
#  {'date': '2021-02-06', 'vax': 601, 'admissions': 1679},
#  {'date': '2021-02-05', 'vax': 1941, 'admissions': 1757},
#  {'date': '2021-02-04', 'vax': 2611, 'admissions': 1907},
#  {'date': '2021-02-03', 'vax': 2282, 'admissions': 2096},
#  {'date': '2021-02-02', 'vax': 1386, 'admissions': 2222},
#  {'date': '2021-02-01', 'vax': 1596, 'admissions': 2347},
#  {'date': '2021-01-31', 'vax': 2757, 'admissions': 2183},
#  {'date': '2021-01-30', 'vax': 10252, 'admissions': 2193},
#  {'date': '2021-01-29', 'vax': 1526, 'admissions': 2379},
#  {'date': '2021-01-28', 'vax': 1271, 'admissions': 2719},
#  {'date': '2021-01-27', 'vax': 1090, 'admissions': 2742},
#  {'date': '2021-01-26', 'vax': 1001, 'admissions': 2799},
#  {'date': '2021-01-25', 'vax': 1326, 'admissions': 2648},
#  {'date': '2021-01-24', 'vax': 610, 'admissions': 2824},
#  {'date': '2021-01-23', 'vax': 774, 'admissions': 2780},
#  {'date': '2021-01-22', 'vax': 1118, 'admissions': 3016},
#  {'date': '2021-01-21', 'vax': 2334, 'admissions': 3237},
#  {'date': '2021-01-20', 'vax': 2723, 'admissions': 3679},
#  {'date': '2021-01-19', 'vax': 2989, 'admissions': 3768},
#  {'date': '2021-01-18', 'vax': 3750, 'admissions': 3711},
#  {'date': '2021-01-17', 'vax': 1284, 'admissions': 3424},
#  {'date': '2021-01-16', 'vax': 1775, 'admissions': 3569},
#  {'date': '2021-01-15', 'vax': 3817, 'admissions': 3295},
#  {'date': '2021-01-14', 'vax': 4854, 'admissions': 3678},
#  {'date': '2021-01-13', 'vax': 8362, 'admissions': 3840},
#  {'date': '2021-01-12', 'vax': 13369, 'admissions': 4134},
#  {'date': '2021-01-11', 'vax': 19312, 'admissions': 3894},
#  {'date': '2021-01-10', 'vax': None, 'admissions': 3571},
#  {'date': '2021-01-09', 'vax': None, 'admissions': 3718},
#  {'date': '2021-01-08', 'vax': None, 'admissions': 3549},
#  {'date': '2021-01-07', 'vax': None, 'admissions': 3849},
#  {'date': '2021-01-06', 'vax': None, 'admissions': 3967},
#  {'date': '2021-01-05', 'vax': None, 'admissions': 3697},
#  {'date': '2021-01-04', 'vax': None, 'admissions': 3587},
#  {'date': '2021-01-03', 'vax': None, 'admissions': 3351},
#  {'date': '2021-01-02', 'vax': None, 'admissions': 3145},
#  {'date': '2021-01-01', 'vax': None, 'admissions': 3010},
#  {'date': '2020-12-31', 'vax': None, 'admissions': 2536},
#  {'date': '2020-12-30', 'vax': None, 'admissions': 2861},
#  {'date': '2020-12-29', 'vax': None, 'admissions': 2886},
#  {'date': '2020-12-28', 'vax': None, 'admissions': 2795},
#  {'date': '2020-12-27', 'vax': None, 'admissions': 2572},
#  {'date': '2020-12-26', 'vax': None, 'admissions': 2298},
#  {'date': '2020-12-25', 'vax': None, 'admissions': 1952},
#  {'date': '2020-12-24', 'vax': None, 'admissions': 1795},
#  {'date': '2020-12-23', 'vax': None, 'admissions': 1980},
#  {'date': '2020-12-22', 'vax': None, 'admissions': 2203},
#  {'date': '2020-12-21', 'vax': None, 'admissions': 2115},
#  {'date': '2020-12-20', 'vax': None, 'admissions': 1976},
#  {'date': '2020-12-19', 'vax': None, 'admissions': 1812},
#  {'date': '2020-12-18', 'vax': None, 'admissions': 1672},
#  {'date': '2020-12-17', 'vax': None, 'admissions': 1873},
#  {'date': '2020-12-16', 'vax': None, 'admissions': 1796},
#  {'date': '2020-12-15', 'vax': None, 'admissions': 1730},
#  {'date': '2020-12-14', 'vax': None, 'admissions': 1746},
#  {'date': '2020-12-13', 'vax': None, 'admissions': 1581},
#  {'date': '2020-12-12', 'vax': None, 'admissions': 1587},
#  {'date': '2020-12-11', 'vax': None, 'admissions': 1450},
#  {'date': '2020-12-10', 'vax': None, 'admissions': 1524},
#  {'date': '2020-12-09', 'vax': None, 'admissions': 1550},
#  {'date': '2020-12-08', 'vax': None, 'admissions': 1528},
#  {'date': '2020-12-07', 'vax': None, 'admissions': 1466},
#  {'date': '2020-12-06', 'vax': None, 'admissions': 1311},
#  {'date': '2020-12-05', 'vax': None, 'admissions': 1186},
#  {'date': '2020-12-04', 'vax': None, 'admissions': 1248},
#  {'date': '2020-12-03', 'vax': None, 'admissions': 1337},
#  {'date': '2020-12-02', 'vax': None, 'admissions': 1262},
#  {'date': '2020-12-01', 'vax': None, 'admissions': 1271},
#  {'date': '2020-11-30', 'vax': None, 'admissions': 1216},
#  {'date': '2020-11-29', 'vax': None, 'admissions': 1215},
#  {'date': '2020-11-28', 'vax': None, 'admissions': 1065},
#  {'date': '2020-11-27', 'vax': None, 'admissions': 1055},
#  {'date': '2020-11-26', 'vax': None, 'admissions': 1198},
#  {'date': '2020-11-25', 'vax': None, 'admissions': 1415},
#  {'date': '2020-11-24', 'vax': None, 'admissions': 1277},
#  {'date': '2020-11-23', 'vax': None, 'admissions': 1385},
#  {'date': '2020-11-22', 'vax': None, 'admissions': 1333},
#  {'date': '2020-11-21', 'vax': None, 'admissions': 1255},
#  {'date': '2020-11-20', 'vax': None, 'admissions': 1316},
#  {'date': '2020-11-19', 'vax': None, 'admissions': 1484},
#  {'date': '2020-11-18', 'vax': None, 'admissions': 1571},
#  {'date': '2020-11-17', 'vax': None, 'admissions': 1491},
#  {'date': '2020-11-16', 'vax': None, 'admissions': 1560},
#  {'date': '2020-11-15', 'vax': None, 'admissions': 1467},
#  {'date': '2020-11-14', 'vax': None, 'admissions': 1388},
#  {'date': '2020-11-13', 'vax': None, 'admissions': 1433},
#  {'date': '2020-11-12', 'vax': None, 'admissions': 1666},
#  {'date': '2020-11-11', 'vax': None, 'admissions': 1711},
#  {'date': '2020-11-10', 'vax': None, 'admissions': 1592},
#  {'date': '2020-11-09', 'vax': None, 'admissions': 1551},
#  {'date': '2020-11-08', 'vax': None, 'admissions': 1488},
#  {'date': '2020-11-07', 'vax': None, 'admissions': 1319},
#  {'date': '2020-11-06', 'vax': None, 'admissions': 1182},
#  {'date': '2020-11-05', 'vax': None, 'admissions': 1346},
#  {'date': '2020-11-04', 'vax': None, 'admissions': 1382},
#  {'date': '2020-11-03', 'vax': None, 'admissions': 1246},
#  {'date': '2020-11-02', 'vax': None, 'admissions': 1331},
#  {'date': '2020-11-01', 'vax': None, 'admissions': 1280},
#  {'date': '2020-10-31', 'vax': None, 'admissions': 1240},
#  {'date': '2020-10-30', 'vax': None, 'admissions': 1109},
#  {'date': '2020-10-29', 'vax': None, 'admissions': 1345},
#  {'date': '2020-10-28', 'vax': None, 'admissions': 1239},
#  {'date': '2020-10-27', 'vax': None, 'admissions': 1190},
#  {'date': '2020-10-26', 'vax': None, 'admissions': 1279},
#  {'date': '2020-10-25', 'vax': None, 'admissions': 1186},
#  {'date': '2020-10-24', 'vax': None, 'admissions': 990},
#  {'date': '2020-10-23', 'vax': None, 'admissions': 997},
#  {'date': '2020-10-22', 'vax': None, 'admissions': 987},
#  {'date': '2020-10-21', 'vax': None, 'admissions': 997},
#  {'date': '2020-10-20', 'vax': None, 'admissions': 925},
#  {'date': '2020-10-19', 'vax': None, 'admissions': 861},
#  {'date': '2020-10-18', 'vax': None, 'admissions': 870},
#  {'date': '2020-10-17', 'vax': None, 'admissions': 785},
#  {'date': '2020-10-16', 'vax': None, 'admissions': 632},
#  {'date': '2020-10-15', 'vax': None, 'admissions': 792},
#  {'date': '2020-10-14', 'vax': None, 'admissions': 706},
#  {'date': '2020-10-13', 'vax': None, 'admissions': 764},
#  {'date': '2020-10-12', 'vax': None, 'admissions': 664},
#  {'date': '2020-10-11', 'vax': None, 'admissions': 628},
#  {'date': '2020-10-10', 'vax': None, 'admissions': 515},
#  {'date': '2020-10-09', 'vax': None, 'admissions': 544},
#  {'date': '2020-10-08', 'vax': None, 'admissions': 513},
#  {'date': '2020-10-07', 'vax': None, 'admissions': 491},
#  {'date': '2020-10-06', 'vax': None, 'admissions': 524},
#  {'date': '2020-10-05', 'vax': None, 'admissions': 472},
#  {'date': '2020-10-04', 'vax': None, 'admissions': 478},
#  {'date': '2020-10-03', 'vax': None, 'admissions': 386},
#  {'date': '2020-10-02', 'vax': None, 'admissions': 371},
#  {'date': '2020-10-01', 'vax': None, 'admissions': 368},
#  {'date': '2020-09-30', 'vax': None, 'admissions': 328},
#  {'date': '2020-09-29', 'vax': None, 'admissions': 310},
#  {'date': '2020-09-28', 'vax': None, 'admissions': 308},
#  {'date': '2020-09-27', 'vax': None, 'admissions': 241},
#  {'date': '2020-09-26', 'vax': None, 'admissions': 245},
#  {'date': '2020-09-25', 'vax': None, 'admissions': 274},
#  {'date': '2020-09-24', 'vax': None, 'admissions': 288},
#  {'date': '2020-09-23', 'vax': None, 'admissions': 314},
#  {'date': '2020-09-22', 'vax': None, 'admissions': 268},
#  {'date': '2020-09-21', 'vax': None, 'admissions': 275},
#  {'date': '2020-09-20', 'vax': None, 'admissions': 237},
#  {'date': '2020-09-19', 'vax': None, 'admissions': 204},
#  {'date': '2020-09-18', 'vax': None, 'admissions': 205},
#  {'date': '2020-09-17', 'vax': None, 'admissions': 199},
#  {'date': '2020-09-16', 'vax': None, 'admissions': 183},
#  {'date': '2020-09-15', 'vax': None, 'admissions': 194},
#  {'date': '2020-09-14', 'vax': None, 'admissions': 172},
#  {'date': '2020-09-13', 'vax': None, 'admissions': 153},
#  {'date': '2020-09-12', 'vax': None, 'admissions': 143},
#  {'date': '2020-09-11', 'vax': None, 'admissions': 135},
#  {'date': '2020-09-10', 'vax': None, 'admissions': 143},
#  {'date': '2020-09-09', 'vax': None, 'admissions': 136},
#  {'date': '2020-09-08', 'vax': None, 'admissions': 99},
#  {'date': '2020-09-07', 'vax': None, 'admissions': 84},
#  {'date': '2020-09-06', 'vax': None, 'admissions': 85},
#  {'date': '2020-09-05', 'vax': None, 'admissions': 94},
#  {'date': '2020-09-04', 'vax': None, 'admissions': 67},
#  {'date': '2020-09-03', 'vax': None, 'admissions': 69},
#  {'date': '2020-09-02', 'vax': None, 'admissions': 79},
#  {'date': '2020-09-01', 'vax': None, 'admissions': 58},
#  {'date': '2020-08-31', 'vax': None, 'admissions': 52},
#  {'date': '2020-08-30', 'vax': None, 'admissions': 38},
#  {'date': '2020-08-29', 'vax': None, 'admissions': 52},
#  {'date': '2020-08-28', 'vax': None, 'admissions': 44},
#  {'date': '2020-08-27', 'vax': None, 'admissions': 69},
#  {'date': '2020-08-26', 'vax': None, 'admissions': 52},
#  {'date': '2020-08-25', 'vax': None, 'admissions': 60},
#  {'date': '2020-08-24', 'vax': None, 'admissions': 41},
#  {'date': '2020-08-23', 'vax': None, 'admissions': 44},
#  {'date': '2020-08-22', 'vax': None, 'admissions': 25},
#  {'date': '2020-08-21', 'vax': None, 'admissions': 49},
#  {'date': '2020-08-20', 'vax': None, 'admissions': 45},
#  {'date': '2020-08-19', 'vax': None, 'admissions': 58},
#  {'date': '2020-08-18', 'vax': None, 'admissions': 56},
#  {'date': '2020-08-17', 'vax': None, 'admissions': 46},
#  {'date': '2020-08-16', 'vax': None, 'admissions': 39},
#  {'date': '2020-08-15', 'vax': None, 'admissions': 38},
#  {'date': '2020-08-14', 'vax': None, 'admissions': 55},
#  {'date': '2020-08-13', 'vax': None, 'admissions': 60},
#  {'date': '2020-08-12', 'vax': None, 'admissions': 51},
#  {'date': '2020-08-11', 'vax': None, 'admissions': 63},
#  {'date': '2020-08-10', 'vax': None, 'admissions': 50},
#  {'date': '2020-08-09', 'vax': None, 'admissions': 53},
#  {'date': '2020-08-08', 'vax': None, 'admissions': 78},
#  {'date': '2020-08-07', 'vax': None, 'admissions': 60},
#  {'date': '2020-08-06', 'vax': None, 'admissions': 52},
#  {'date': '2020-08-05', 'vax': None, 'admissions': 60},
#  {'date': '2020-08-04', 'vax': None, 'admissions': 58},
#  {'date': '2020-08-03', 'vax': None, 'admissions': 74},
#  {'date': '2020-08-02', 'vax': None, 'admissions': 57},
#  {'date': '2020-08-01', 'vax': None, 'admissions': 50},
#  {'date': '2020-07-31', 'vax': None, 'admissions': 55},
#  {'date': '2020-07-30', 'vax': None, 'admissions': 75},
#  {'date': '2020-07-29', 'vax': None, 'admissions': 63},
#  {'date': '2020-07-28', 'vax': None, 'admissions': 69},
#  {'date': '2020-07-27', 'vax': None, 'admissions': 82},
#  {'date': '2020-07-26', 'vax': None, 'admissions': 64},
#  {'date': '2020-07-25', 'vax': None, 'admissions': 65},
#  {'date': '2020-07-24', 'vax': None, 'admissions': 93},
#  {'date': '2020-07-23', 'vax': None, 'admissions': 109},
#  {'date': '2020-07-22', 'vax': None, 'admissions': 82},
#  {'date': '2020-07-21', 'vax': None, 'admissions': 79},
#  {'date': '2020-07-20', 'vax': None, 'admissions': 86},
#  {'date': '2020-07-19', 'vax': None, 'admissions': 72},
#  {'date': '2020-07-18', 'vax': None, 'admissions': 48},
#  {'date': '2020-07-17', 'vax': None, 'admissions': 83},
#  {'date': '2020-07-16', 'vax': None, 'admissions': 114},
#  {'date': '2020-07-15', 'vax': None, 'admissions': 116},
#  {'date': '2020-07-14', 'vax': None, 'admissions': 122},
#  {'date': '2020-07-13', 'vax': None, 'admissions': 137},
#  {'date': '2020-07-12', 'vax': None, 'admissions': 72},
#  {'date': '2020-07-11', 'vax': None, 'admissions': 97},
#  {'date': '2020-07-10', 'vax': None, 'admissions': 104},
#  {'date': '2020-07-09', 'vax': None, 'admissions': 136},
#  {'date': '2020-07-08', 'vax': None, 'admissions': 141},
#  {'date': '2020-07-07', 'vax': None, 'admissions': 148},
#  {'date': '2020-07-06', 'vax': None, 'admissions': 150},
#  {'date': '2020-07-05', 'vax': None, 'admissions': 131},
#  {'date': '2020-07-04', 'vax': None, 'admissions': 120},
#  {'date': '2020-07-03', 'vax': None, 'admissions': 146},
#  {'date': '2020-07-02', 'vax': None, 'admissions': 149},
#  {'date': '2020-07-01', 'vax': None, 'admissions': 201},
#  {'date': '2020-06-30', 'vax': None, 'admissions': 189},
#  {'date': '2020-06-29', 'vax': None, 'admissions': 172},
#  {'date': '2020-06-28', 'vax': None, 'admissions': 155},
#  {'date': '2020-06-27', 'vax': None, 'admissions': 209},
#  {'date': '2020-06-26', 'vax': None, 'admissions': 248},
#  {'date': '2020-06-25', 'vax': None, 'admissions': 256},
#  {'date': '2020-06-24', 'vax': None, 'admissions': 262},
#  {'date': '2020-06-23', 'vax': None, 'admissions': 275},
#  {'date': '2020-06-22', 'vax': None, 'admissions': 318},
#  {'date': '2020-06-21', 'vax': None, 'admissions': 215},
#  {'date': '2020-06-20', 'vax': None, 'admissions': 184},
#  {'date': '2020-06-19', 'vax': None, 'admissions': 253},
#  {'date': '2020-06-18', 'vax': None, 'admissions': 312},
#  {'date': '2020-06-17', 'vax': None, 'admissions': 334},
#  {'date': '2020-06-16', 'vax': None, 'admissions': 354},
#  {'date': '2020-06-15', 'vax': None, 'admissions': 365},
#  {'date': '2020-06-14', 'vax': None, 'admissions': 306},
#  {'date': '2020-06-13', 'vax': None, 'admissions': 265},
#  {'date': '2020-06-12', 'vax': None, 'admissions': 298},
#  {'date': '2020-06-11', 'vax': None, 'admissions': 330},
#  {'date': '2020-06-10', 'vax': None, 'admissions': 402},
#  {'date': '2020-06-09', 'vax': None, 'admissions': 397},
#  {'date': '2020-06-08', 'vax': None, 'admissions': 348},
#  {'date': '2020-06-07', 'vax': None, 'admissions': 323},
#  {'date': '2020-06-06', 'vax': None, 'admissions': 306},
#  {'date': '2020-06-05', 'vax': None, 'admissions': 380},
#  {'date': '2020-06-04', 'vax': None, 'admissions': 458},
#  {'date': '2020-06-03', 'vax': None, 'admissions': 491},
#  {'date': '2020-06-02', 'vax': None, 'admissions': 553},
#  {'date': '2020-06-01', 'vax': None, 'admissions': 522},
#  {'date': '2020-05-31', 'vax': None, 'admissions': 446},
#  {'date': '2020-05-30', 'vax': None, 'admissions': 466},
#  {'date': '2020-05-29', 'vax': None, 'admissions': 499},
#  {'date': '2020-05-28', 'vax': None, 'admissions': 570},
#  {'date': '2020-05-27', 'vax': None, 'admissions': 589},
#  {'date': '2020-05-26', 'vax': None, 'admissions': 578},
#  {'date': '2020-05-25', 'vax': None, 'admissions': 498},
#  {'date': '2020-05-24', 'vax': None, 'admissions': 497},
#  {'date': '2020-05-23', 'vax': None, 'admissions': 504},
#  {'date': '2020-05-22', 'vax': None, 'admissions': 638},
#  {'date': '2020-05-21', 'vax': None, 'admissions': 715},
#  {'date': '2020-05-20', 'vax': None, 'admissions': 732},
#  {'date': '2020-05-19', 'vax': None, 'admissions': 752},
#  {'date': '2020-05-18', 'vax': None, 'admissions': 733},
#  {'date': '2020-05-17', 'vax': None, 'admissions': 673},
#  {'date': '2020-05-16', 'vax': None, 'admissions': 671},
#  {'date': '2020-05-15', 'vax': None, 'admissions': 738},
#  {'date': '2020-05-14', 'vax': None, 'admissions': 763},
#  {'date': '2020-05-13', 'vax': None, 'admissions': 804},
#  {'date': '2020-05-12', 'vax': None, 'admissions': 844},
#  {'date': '2020-05-11', 'vax': None, 'admissions': 866},
#  {'date': '2020-05-10', 'vax': None, 'admissions': 756},
#  {'date': '2020-05-09', 'vax': None, 'admissions': 798},
#  {'date': '2020-05-08', 'vax': None, 'admissions': 743},
#  {'date': '2020-05-07', 'vax': None, 'admissions': 998},
#  {'date': '2020-05-06', 'vax': None, 'admissions': 1040},
#  {'date': '2020-05-05', 'vax': None, 'admissions': 959},
#  {'date': '2020-05-04', 'vax': None, 'admissions': 1063},
#  {'date': '2020-05-03', 'vax': None, 'admissions': 1044},
#  {'date': '2020-05-02', 'vax': None, 'admissions': 980},
#  {'date': '2020-05-01', 'vax': None, 'admissions': 1081},
#  {'date': '2020-04-30', 'vax': None, 'admissions': 1227},
#  {'date': '2020-04-29', 'vax': None, 'admissions': 1295},
#  {'date': '2020-04-28', 'vax': None, 'admissions': 1296},
#  {'date': '2020-04-27', 'vax': None, 'admissions': 1344},
#  {'date': '2020-04-26', 'vax': None, 'admissions': 1208},
#  {'date': '2020-04-25', 'vax': None, 'admissions': 1080},
#  {'date': '2020-04-24', 'vax': None, 'admissions': 1277},
#  {'date': '2020-04-23', 'vax': None, 'admissions': 1289},
#  {'date': '2020-04-22', 'vax': None, 'admissions': 1310},
#  {'date': '2020-04-21', 'vax': None, 'admissions': 1495},
#  {'date': '2020-04-20', 'vax': None, 'admissions': 1522},
#  {'date': '2020-04-19', 'vax': None, 'admissions': 1475},
#  {'date': '2020-04-18', 'vax': None, 'admissions': 1411},
#  {'date': '2020-04-17', 'vax': None, 'admissions': 1674},
#  {'date': '2020-04-16', 'vax': None, 'admissions': 1777},
#  {'date': '2020-04-15', 'vax': None, 'admissions': 1608},
#  {'date': '2020-04-14', 'vax': None, 'admissions': 1859},
#  {'date': '2020-04-13', 'vax': None, 'admissions': 1912},
#  {'date': '2020-04-12', 'vax': None, 'admissions': 1791},
#  {'date': '2020-04-11', 'vax': None, 'admissions': 1955},
#  {'date': '2020-04-10', 'vax': None, 'admissions': 2196},
#  {'date': '2020-04-09', 'vax': None, 'admissions': 2340},
#  {'date': '2020-04-08', 'vax': None, 'admissions': 2619},
#  {'date': '2020-04-07', 'vax': None, 'admissions': 2744},
#  {'date': '2020-04-06', 'vax': None, 'admissions': 2679},
#  {'date': '2020-04-05', 'vax': None, 'admissions': 2592},
#  {'date': '2020-04-04', 'vax': None, 'admissions': 2593},
#  {'date': '2020-04-03', 'vax': None, 'admissions': 2564},
#  {'date': '2020-04-02', 'vax': None, 'admissions': 2932},
#  {'date': '2020-04-01', 'vax': None, 'admissions': 3099},
#  {'date': '2020-03-31', 'vax': None, 'admissions': 2447},
#  {'date': '2020-03-30', 'vax': None, 'admissions': 2817},
#  {'date': '2020-03-29', 'vax': None, 'admissions': 2186},
#  {'date': '2020-03-28', 'vax': None, 'admissions': 1873},
#  {'date': '2020-03-27', 'vax': None, 'admissions': 1931},
#  {'date': '2020-03-26', 'vax': None, 'admissions': 1639},
#  {'date': '2020-03-25', 'vax': None, 'admissions': 1755},
#  {'date': '2020-03-24', 'vax': None, 'admissions': 1544},
#  {'date': '2020-03-23', 'vax': None, 'admissions': 1128},
#  {'date': '2020-03-22', 'vax': None, 'admissions': 859},
#  {'date': '2020-03-21', 'vax': None, 'admissions': 777},
#  {'date': '2020-03-20', 'vax': None, 'admissions': 691},
#  {'date': '2020-03-19', 'vax': None, 'admissions': 586}]

# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from uk_covid19 import Cov19API

# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100
with open("case_and_admission.json", "rt") as INFILE:
    jsondata=json.load(INFILE)
    
def parse_date(datestring):
    """ Convert a date string into a pandas datetime object """
    return pd.to_datetime(datestring, format="%Y-%m-%d")
def wrangle_data(rawdata):
    Mydatalist=rawdata['data']
    my_dates=[dictionary['date'] for dictionary in Mydatalist]
    my_dates.sort()
    startdate=parse_date(my_dates[0])
    enddate=parse_date(my_dates[-1])
    print (startdate, ' to ', enddate)
    index=pd.date_range(startdate, enddate, freq='D')
    cases_admis=pd.DataFrame(index=index, columns=['vax', 'admissions'])
    cases_admis
    
    for entry in Mydatalist: # each entry is a dictionary with date, cases, hospital and deaths
        date=parse_date(entry['date'])
        for column in ['vax', 'admissions']:
            if pd.isna(cases_admis.loc[date, column]):  
                value= float(entry[column]) if entry[column]!=None else 0.0
                cases_admis.loc[date, column]=value
            
    cases_admis.fillna(0.0, inplace=True)
    return cases_admis
df=wrangle_data(jsondata)
df
# Out:
# 2020-03-19 00:00:00  to  2021-10-25 00:00:00
#             vax  admissions
# 2020-03-19  0.0       586.0
# 2020-03-20  0.0       691.0
# 2020-03-21  0.0       777.0
# 2020-03-22  0.0       859.0
# 2020-03-23  0.0      1128.0
# ...         ...         ...
# 2021-10-21  0.0       799.0
# 2021-10-22  0.0       760.0
# 2021-10-23  0.0       756.0
# 2021-10-24  0.0       829.0
# 2021-10-25  0.0       865.0
#
# [586 rows x 2 columns]

# %% [markdown]
# ## Download current data

# %% [markdown]
# Give your users an option to refresh the dataset - a "refresh" button will do. The button callback should
# * call the code that accesses the API and download some fresh raw data;
# * wrangle that data into a dataframe and update the corresponding (global) variable for plotting;
# * optionally: force a redraw of the graph and give the user some fredback.
#
# Once you get it to work, you may want to wrap your API call inside an exception handler, so that the user is informed, the "canned" data are not overwritten and nothing crashes if for any reason the server cannot be reached or data are not available.
#
# After you refresh the data, graphs will not update until the user interacts with a widget. You can trick ```iPywidgets``` into redrawing the graph by simulating interaction, as in the ```refresh_graph``` function we define in the Graph and Analysis section below.
#
# Clicking on the button below just generates some more random data and refreshes the graph. The button should read *Fetch Data*. If you see anything else, take a deep breath :)

# %%
# Place your API access code in this function. Do not call this function directly; it will be called by 
# the button callback. 
def access_api():
    return {}
# def access_api():
#     filters = [
#         'areaType=nation',
#         'areaName=England'
#         ]

#     structure = {
#         "date":"date",
#         "vax": "newPeopleVaccinatedCompleteByPublishDate",
#         "admissions": "newAdmissions",
#     }
#     api = Cov19API(filters=filters, structure=structure)
#     case_and_admission=api.get_json()
#     import json
#     with open("case_and_admission.json", "wt") as OUTF:
#         json.dump(case_and_admission, OUTF)

# %%
# Printout from this function will be lost in Voila unless captured in an
# output widget - therefore, we give feedback to the user by changing the 
# appearance of the button
def api_button_callback(button):
    """ Button callback - it must take the button as its parameter (unused in this case).
    Accesses API, wrangles data, updates global variable df used for plotting. """
    # Get fresh data from the API. If you have time, include some error handling
    # around this call.
    apidata=access_api()
    # wrangle the data and overwrite the dataframe for plotting
    global df
    df=wrangle_data(apidata)
    # the graph won't refresh until the user interacts with the widget.
    # this function simulates the interaction, see Graph and Analysis below.
    # you can omit this step in the first instance
    refresh_graph()
    # after all is done, you can switch the icon on the button to a "check" sign
    # and optionally disable the button - it won't be needed again. You can use icons
    # "unlink" or "times" and change the button text to "Unavailable" in case the 
    # api call fails.
    apibutton.icon="check"
    # apibutton.disabled=True

    
apibutton=wdg.Button(
    description='PANIC', # you may want to change this...
    disabled=False,
    button_style='danger', # 'success', 'info', 'warning', 'danger' or ''
    tooltip="Keep calm and carry on",
    # FontAwesome names without the `fa-` prefix - try "download"
    icon='exclamation-triangle'
)

# remember to register your button callback function with the button
apibutton.on_click(api_button_callback) # the name of your function inside these brackets

display(apibutton)

def timeseries_graph(walk):
    df[walk].plot()
    plt.show()

whichwalk=wdg.Dropdown(
    options=['vax', 'admissions'],
    value='admissions',
    description='Stats:',
    disabled=False
)

def refresh_graph():
    current=whichwalk.value
    if current==whichwalk.options[0]:
        other=whichwalk.options[1]
    else:
        other=whichwalk.options[0]
    whichwalklk.value=other
    whichwalklk.value=current

graph=wdg.interactive_output(timeseries_graph, {'walk': whichwalk})

display(whichwalk, graph)

# run all cells before clicking on this button
# Out:
# Button(button_style='danger', description='PANIC', icon='exclamation-triangle', style=ButtonStyle(), tooltip='…
# Dropdown(description='Stats:', index=1, options=('vax', 'admissions'), value='admissions')
# Output()

# %% [markdown]
# ## Graphs and Analysis

# %% [markdown]
# Include at least one graph with interactive controls, as well as some instructions for the user and/or comments on what the graph represents and how it should be explored (this example shows two random walks)

# %%
#The figure shows vaccinations with the admissions of covid positive patients to the hospital. The first plot is interactive and you can see the log and linear plots for vaccinations and 
#admissions the second graph has two y-axis to display both the

# %% [markdown]
# ## Deploying the dashboard
#
# Once your code is ready and you are satisfied with the appearance of the graphs, replace all the text boxes above with the explanations you would like a dashboard user to see. The next step is deploying the dashboard online - there are several [options](https://voila.readthedocs.io/en/stable/deploy.html) for this, we suggest deploying as a [Binder](https://mybinder.org/). This is basically the same technique that has been used to package this tutorial and to deploy this template dashboard. The instructions may seem a bit involved, but the actual steps are surprisingly easy - we will be going through them together during a live session. You will need an account on [GitHub](https://github.com/) for this - if you don't have one already, now it's the time to create it.

# %% [markdown]
# **Author and Copyright Notice** Remember if you deploy this dashboard as a Binder it will be publicly accessible. Take credit for your work! Also acknowledge the data source: *Based on UK Government [data](https://coronavirus.data.gov.uk/) published by [Public Health England](https://www.gov.uk/government/organisations/public-health-england).*
